# %% [markdown]
# ## Get all the costs results :

# %%
import pandas as pd
#sourceCPLEX = "D:/DTU-Courses/DTU-Thesis/berth_allocation/MCBAP-multi-port-berth-allocation-problem/results_jobs/benchmarks_CPLEX/CPLEX_N4_N15_results_5min.csv"
sourceCPLEX = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_CPLEX/CPLEX_NLarge_results_2400s_all.csv"
sourceHeur = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_HEUR"
algo_folder="finalGRASP"
expnb=5
exp="GRASPonly4local21_01_05"
Nmin=11
Nmax=15

def get_results_cost(type):
    dataCPLEX = pd.read_csv(sourceCPLEX)
    if type == 'large':
        if exp=="GRASPonly4local21":
            dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/NLarge_concatenete2.csv")
        else:
            dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/NLarge_concatenete.csv")
    else:
        for i in range(Nmin, Nmax):
            this_dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/N{i}_N{i}.csv")
            dataHeur = pd.concat([dataHeur, this_dataHeur], ignore_index=True)
    merged_df = pd.merge(dataCPLEX, dataHeur, how='inner', on=['Seed', 'N', 'Nout', 'qli'])
    merged_df["diff"] = (merged_df["HeurCost"] - merged_df["CPLEX"])/merged_df["CPLEX"]*100
    if type == 'large':
        merged_df.to_csv(f"{sourceHeur}/{algo_folder}/{exp}/Large_diff_{exp}.csv", index=False)
    else:
        merged_df.to_csv(f"{sourceHeur}/{algo_folder}/{exp}/N{Nmin}_N{Nmax}_diff{exp}.csv", index=False)
    return merged_df
merged_df = get_results_cost('large')
mean_diff = merged_df.groupby(['N', 'Nout'])['diff'].mean().reset_index()
mean_diff
# Out:
#     N  Nout      diff
# 0   0     0       NaN
# 1  30     5  6.073738
# 2  30    10  9.127256
# 3  50     5 -1.073187
# 4  50    10 -2.704954

# %%
import pandas as pd
#sourceCPLEX = "D:/DTU-Courses/DTU-Thesis/berth_allocation/MCBAP-multi-port-berth-allocation-problem/results_jobs/benchmarks_CPLEX/CPLEX_N4_N15_results_5min.csv"
sourceCPLEX = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_CPLEX/CPLEX_NLarge_results_2400s_all.csv"
sourceHeur = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_HEUR"
algo_folder="finalGRASP"
expnb=5
exp="GRASPonly4local21_01_1"
Nmin=11
Nmax=15

def get_results_cost(type):
    dataCPLEX = pd.read_csv(sourceCPLEX)
    if type == 'large':
        if exp=="GRASPonly4local21":
            dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/NLarge_concatenete2.csv")
        else:
            dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/NLarge_concatenete.csv")
    else:
        for i in range(Nmin, Nmax):
            this_dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/N{i}_N{i}.csv")
            dataHeur = pd.concat([dataHeur, this_dataHeur], ignore_index=True)
    merged_df = pd.merge(dataCPLEX, dataHeur, how='inner', on=['Seed', 'N', 'Nout', 'qli'])
    merged_df["diff"] = (merged_df["HeurCost"] - merged_df["CPLEX"])/merged_df["CPLEX"]*100
    if type == 'large':
        merged_df.to_csv(f"{sourceHeur}/{algo_folder}/{exp}/Large_diff_{exp}.csv", index=False)
    else:
        merged_df.to_csv(f"{sourceHeur}/{algo_folder}/{exp}/N{Nmin}_N{Nmax}_diff{exp}.csv", index=False)
    return merged_df
merged_df = get_results_cost('large')
mean_diff = merged_df.groupby(['N', 'Nout'])['diff'].mean().reset_index()
mean_diff
# Out:
#     N  Nout      diff
# 0   0     0       NaN
# 1  30     5  5.019585
# 2  30    10  8.645882
# 3  50     5 -1.586352
# 4  50    10 -3.080853

# %%
import pandas as pd
#sourceCPLEX = "D:/DTU-Courses/DTU-Thesis/berth_allocation/MCBAP-multi-port-berth-allocation-problem/results_jobs/benchmarks_CPLEX/CPLEX_N4_N15_results_5min.csv"
sourceCPLEX = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_CPLEX/CPLEX_NLarge_results_2400s_all.csv"
sourceHeur = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_HEUR"
algo_folder="finalGRASP"
expnb=5
exp="GRASPonly4local21_01_2"
Nmin=11
Nmax=15

def get_results_cost(type):
    dataCPLEX = pd.read_csv(sourceCPLEX)
    if type == 'large':
        if exp=="GRASPonly4local21":
            dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/NLarge_concatenete2.csv")
        else:
            dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/NLarge_concatenete.csv")
    else:
        for i in range(Nmin, Nmax):
            this_dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/N{i}_N{i}.csv")
            dataHeur = pd.concat([dataHeur, this_dataHeur], ignore_index=True)
    merged_df = pd.merge(dataCPLEX, dataHeur, how='inner', on=['Seed', 'N', 'Nout', 'qli'])
    merged_df["diff"] = (merged_df["HeurCost"] - merged_df["CPLEX"])/merged_df["CPLEX"]*100
    if type == 'large':
        merged_df.to_csv(f"{sourceHeur}/{algo_folder}/{exp}/Large_diff_{exp}.csv", index=False)
    else:
        merged_df.to_csv(f"{sourceHeur}/{algo_folder}/{exp}/N{Nmin}_N{Nmax}_diff{exp}.csv", index=False)
    return merged_df
merged_df = get_results_cost('large')
mean_diff = merged_df.groupby(['N', 'Nout'])['diff'].mean().reset_index()
mean_diff
# Out:
#     N  Nout      diff
# 0   0     0       NaN
# 1  30     5  4.645936
# 2  30    10  7.981725
# 3  50     5 -2.356252
# 4  50    10 -2.249388

# %%
import pandas as pd
#sourceCPLEX = "D:/DTU-Courses/DTU-Thesis/berth_allocation/MCBAP-multi-port-berth-allocation-problem/results_jobs/benchmarks_CPLEX/CPLEX_N4_N15_results_5min.csv"
sourceCPLEX = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_CPLEX/CPLEX_NLarge_results_2400s_all.csv"
sourceHeur = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_HEUR"
algo_folder="finalGRASP"
expnb=5
exp="GRASPonly4local21_01_3"
Nmin=11
Nmax=15

def get_results_cost(type):
    dataCPLEX = pd.read_csv(sourceCPLEX)
    if type == 'large':
        if exp=="GRASPonly4local21":
            dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/NLarge_concatenete2.csv")
        else:
            dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/NLarge_concatenete.csv")
    else:
        for i in range(Nmin, Nmax):
            this_dataHeur = pd.read_csv(f"{sourceHeur}/{algo_folder}/{exp}/N{i}_N{i}.csv")
            dataHeur = pd.concat([dataHeur, this_dataHeur], ignore_index=True)
    merged_df = pd.merge(dataCPLEX, dataHeur, how='inner', on=['Seed', 'N', 'Nout', 'qli'])
    merged_df["diff"] = (merged_df["HeurCost"] - merged_df["CPLEX"])/merged_df["CPLEX"]*100
    if type == 'large':
        merged_df.to_csv(f"{sourceHeur}/{algo_folder}/{exp}/Large_diff_{exp}.csv", index=False)
    else:
        merged_df.to_csv(f"{sourceHeur}/{algo_folder}/{exp}/N{Nmin}_N{Nmax}_diff{exp}.csv", index=False)
    return merged_df
merged_df = get_results_cost('large')
mean_diff = merged_df.groupby(['N', 'Nout'])['diff'].mean().reset_index()
mean_diff
# Out:
#     N  Nout      diff
# 0  30     5  5.114299
# 1  30    10  7.395572
# 2  50     5  1.175780
# 3  50    10 -4.608710

# %%
from getdict_results import *

# %%
sourceHeur = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_HEUR"
algo_folder="finalGRASP"
exp="GRASPonly4local21_01_3"
listNin = []
listNout = []
listqli = []
listseed = []
listobj = []
for Nin in [30,50]:
    for qli in [10,20,40,80]:
        for seed in [2,3,4,5]:
            for Nout in [5,10]:
                try:
                    sols = getsolfromfileHEUR(algo_folder=algo_folder, exp=exp, seed=seed,Nin=Nin,Nout=Nout,qli=qli)
                    listobj.append(sols["objectif"])
                    listNin.append(Nin)
                    listNout.append(Nout)
                    listqli.append(qli)
                    listseed.append(seed)                    
                except:
                    pass
print(len(listseed))
print(len(listobj))
print(len(listNin))
print(len(listNout))
print(len(listqli))
dataframe = pd.DataFrame({"N":listNin, "Nout":listNout, "qli":listqli, "Seed":listseed, "HeurCost":listobj})
# Out:
# 54
# 54
# 54
# 54
# 54

# %%
dataframe.to_csv(f"{sourceHeur}/{algo_folder}/{exp}/NLarge_concatenete.csv", index=False)

# %%
dataframe
# Out:
#      N  Nout  qli  seed   HeurCost
# 0   30     5   10     2  2126742.0
# 1   30    10   10     2  2700809.0
# 2   30     5   10     3  1799955.0
# 3   30    10   10     3  2443872.0
# 4   30     5   10     4  1969569.0
# 5   30    10   10     4  2612914.0
# 6   30     5   10     5  2071143.0
# 7   30    10   10     5  2541220.0
# 8   30     5   20     2  2173746.0
# 9   30    10   20     2  2663104.0
# 10  30     5   20     3  1831814.0
# 11  30    10   20     3  2445009.0
# 12  30     5   20     4  2001496.0
# 13  30    10   20     4  2593571.0
# 14  30     5   20     5  2083681.0
# 15  30    10   20     5  2559416.0
# 16  30     5   40     2  2253358.0
# 17  30    10   40     2  2708529.0
# 18  30     5   40     3  1881063.0
# 19  30    10   40     3  2521359.0
# 20  30    10   40     4  2776991.0
# 21  30    10   40     5  2731391.0
# 22  30    10   80     2  3397014.0
# 23  30    10   80     3  3042224.0
# 24  30    10   80     4  3311822.0
# 25  30    10   80     5  3027863.0
# 26  50     5   10     2  5555042.0
# 27  50    10   10     2  7713419.0
# 28  50     5   10     3  4729693.0
# 29  50    10   10     3  6889015.0
# 30  50     5   10     4  4738068.0
# 31  50    10   10     4  7537859.0
# 32  50     5   10     5  5056498.0
# 33  50    10   10     5  7385087.0
# 34  50     5   20     2  5797036.0
# 35  50    10   20     2  7473403.0
# 36  50     5   20     3  4797454.0
# 37  50    10   20     3  7049975.0
# 38  50     5   20     4  4783459.0
# 39  50    10   20     4  7318618.0
# 40  50     5   20     5  5293283.0
# 41  50    10   20     5  7770341.0
# 42  50     5   40     2  6262618.0
# 43  50    10   40     2  8037386.0
# 44  50     5   40     3  5152576.0
# 45  50    10   40     3  7581153.0
# 46  50     5   40     4  5244395.0
# 47  50    10   40     4  8601339.0
# 48  50     5   40     5  5616579.0
# 49  50    10   40     5  8184552.0
# 50  50    10   80     2  8935528.0
# 51  50    10   80     3  9093435.0
# 52  50    10   80     4  9896399.0
# 53  50    10   80     5  9523846.0

# %% [markdown]
# ## Get results in json :

# %%
from getdict_results import *

# %%
seed=2
Nin=30
qli=10
Nout=5

# %% [markdown]
# ## Get vizualization from the sol

# %%
file = "D:/DTU-Courses/DTU-Thesis/berth_allocation/results_jobs/benchmarks_CPLEX/sols_2400s/CPLEX_sol_{}_{}_{}_{}.csv".format(seed,Nin,Nout,qli)
results_sol = pd.read_csv(file)
listx=list(results_sol[results_sol['first']=='x']['second'])[0].replace(' ','').split('\n')

# %%
from make_graphs import *
getgraphs_port(algo_folder, exp, seed,Nin,Nout,qli, 'large', 5)

# %% [markdown]
# ## Cost comparison before and after :

# %%
exp="GRASPonly4local21"
dataset21 = make_datasetiterSoft(algo_folder=algo_folder, exp=exp, seed=seed,Nin=Nin,Nout=Nout,qli=qli)
#for col in ['delay_cost_visit', 'penalty_visit', 'fuel_cost_visit', 'handling_cost_visit', 'waiting_cost_visit','n','c', 'when']:
#    dataset[col] = dataset[col].astype(int)

# %%
exp="GRASPonly4local23"
dataset23 = make_datasetiterSoft(algo_folder=algo_folder, exp=exp, seed=seed,Nin=Nin,Nout=Nout,qli=qli)

# %%
exp="GRASPonly4local41"
dataset41 = make_datasetiterSoft(algo_folder=algo_folder, exp=exp, seed=seed,Nin=Nin,Nout=Nout,qli=qli)

# %%
exp="GRASPonly4local43"
dataset43 =  make_datasetiterSoft(algo_folder=algo_folder, exp=exp, seed=seed,Nin=Nin,Nout=Nout,qli=qli)

# %%
dataset=dataset43

# %%
dataset21['inst_type']="2_1"
dataset23['inst_type']="2_3"
dataset41['inst_type']="4_1"
dataset43['inst_type']="4_3"
dataset21.rename(columns={
    'cost_solheur': 'Heur Cost',
    'cost_sollocal': 'Local Cost',
    'delay_cost_sollocal': 'Delay Cost Local',
    'penalty_sollocal': 'Penalty Local',
    'fuel_cost_sollocal': 'Fuel Cost Local',
    'handling_cost_sollocal': 'Handling Cost Local',
    'waiting_cost_sollocal': 'Waiting Cost Local',
    'delay_cost_solheur': 'Delay Cost Heur',
    'penalty_solheur': 'Penalty Heur',
    'fuel_cost_solheur': 'Fuel Cost Heur',
    'handling_cost_solheur': 'Handling Cost Heur',
    'waiting_cost_solheur': 'Waiting Cost Heur'
}, inplace=True)
dataset23.rename(columns={
    'cost_solheur': 'Heur Cost',
    'cost_sollocal': 'Local Cost',
    'delay_cost_sollocal': 'Delay Cost Local',
    'penalty_sollocal': 'Penalty Local',
    'fuel_cost_sollocal': 'Fuel Cost Local',
    'handling_cost_sollocal': 'Handling Cost Local',
    'waiting_cost_sollocal': 'Waiting Cost Local',
    'delay_cost_solheur': 'Delay Cost Heur',
    'penalty_solheur': 'Penalty Heur',
    'fuel_cost_solheur': 'Fuel Cost Heur',
    'handling_cost_solheur': 'Handling Cost Heur',
    'waiting_cost_solheur': 'Waiting Cost Heur'
}, inplace=True)
dataset41.rename(columns={
    'cost_solheur': 'Heur Cost',
    'cost_sollocal': 'Local Cost',
    'delay_cost_sollocal': 'Delay Cost Local',
    'penalty_sollocal': 'Penalty Local',
    'fuel_cost_sollocal': 'Fuel Cost Local',
    'handling_cost_sollocal': 'Handling Cost Local',
    'waiting_cost_sollocal': 'Waiting Cost Local',
    'delay_cost_solheur': 'Delay Cost Heur',
    'penalty_solheur': 'Penalty Heur',
    'fuel_cost_solheur': 'Fuel Cost Heur',
    'handling_cost_solheur': 'Handling Cost Heur',
    'waiting_cost_solheur': 'Waiting Cost Heur'
}, inplace=True)
dataset43.rename(columns={
    'cost_solheur': 'Heur Cost',
    'cost_sollocal': 'Local Cost',
    'delay_cost_sollocal': 'Delay Cost Local',
    'penalty_sollocal': 'Penalty Local',
    'fuel_cost_sollocal': 'Fuel Cost Local',
    'handling_cost_sollocal': 'Handling Cost Local',
    'waiting_cost_sollocal': 'Waiting Cost Local',
    'delay_cost_solheur': 'Delay Cost Heur',
    'penalty_solheur': 'Penalty Heur',
    'fuel_cost_solheur': 'Fuel Cost Heur',
    'handling_cost_solheur': 'Handling Cost Heur',
    'waiting_cost_solheur': 'Waiting Cost Heur'
}, inplace=True)

# %%
all_datasets = pd.concat([ dataset21, dataset23, dataset41, dataset43])

# %%
all_datasets[all_datasets['inst_type']=='2_1']['Local Cost']
# Out:
# 0       2676939.0
# 1       2455105.0
# 2       3941171.0
# 3       3303423.0
# 4       3153903.0
#           ...
# 2041    3615771.0
# 2042    2889251.0
# 2043    3608748.0
# 2044    2883162.0
# 2045    2294068.0
# Name: Local Cost, Length: 2046, dtype: float64

# %%
dataset.columns
# Out:
# Index(['iter', 'inst', 'objectif', 'chosen_tacticoneboat', 'chosen_reversed',
#        'chosen_tacticallboats', 'chosen_reversedtacticallboats',
#        'chosen_tacticlocalsearch', 'chosen_indexoneship',
#        'chosen_indexallship', 'chosen_indexreversedallship',
#        'chosen_indexrateconstrained', 'chosen_indexproptoremove', 'Heur Cost',
#        'Delay Cost Heur', 'Waiting Cost Heur', 'Penalty Heur',
#        'Handling Cost Heur', 'Fuel Cost Heur', 'Local Cost',
#        'Delay Cost Local', 'Waiting Cost Local', 'Penalty Local',
#        'Handling Cost Local', 'Fuel Cost Local', 'timeheur', 'timelocal',
#        'proba_tacticboat', 'proba_tacticall', 'proba_tacticlocalsearch',
#        'oneboatdistance', 'oneboatcost', 'oneboattime', 'allboatsdist',
#        'allboatstime', 'allboatscost', 'rateconstained', 'failed', 'better',
#        'reconstruct', 'pathrelinking', 'usedLocalSearch', 'average_cost_elite',
#        'average_dist_elite', 'pushimprove'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Create a new DataFrame where each row's 'Local Cost' is the minimum 'Local Cost' up to that row
min_costs = dataset['Local Cost'].cummin()

# Get the iterations where the 'Local Cost' decreased
decreasing_iterations = min_costs[min_costs.diff() < 0].index

# Get the 'Local Cost' at the decreasing iterations
decreasing_costs = min_costs[decreasing_iterations]

# Add the last point
decreasing_iterations = decreasing_iterations.append(pd.Index([dataset['iter'].max()]))
decreasing_costs = decreasing_costs.append(pd.Series(min_costs.iloc[-1]))

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(decreasing_iterations, decreasing_costs, marker='o')

# Adding titles and labels
plt.title('Decrease in Local Cost Over Iterations')
plt.xlabel('Iteration')
plt.ylabel('Local Cost')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a new Series where each value is the minimum 'Local Cost' up to that row
min_local_costs = dataset['Local Cost'].cummin()

# Get the iterations where the 'Local Cost' decreased
decreasing_iterations_local = min_local_costs[min_local_costs.diff() < 0].index

# Get the 'Local Cost' and 'Heur Cost' at the decreasing iterations
decreasing_local_costs = min_local_costs[decreasing_iterations_local]
decreasing_heur_costs = dataset.loc[decreasing_iterations_local, 'Heur Cost']


# Data preparation
plot_data = pd.DataFrame({
    'Iteration': decreasing_local_costs.index,
    'Heuristic Cost': decreasing_heur_costs.values,
    'Local Cost': decreasing_local_costs.values
})

# Setting the positions and width for the bars
pos = list(range(len(plot_data['Iteration'])))
width = 0.25

# Plotting the bars
fig, ax = plt.subplots(figsize=(10,5))

# Create a bar with Heuristic Cost data, in position pos
plt.bar(pos, 
        #using plot_data['Heuristic Cost'] data,
        plot_data['Heuristic Cost'], 
        # of width
        width, 
        # with color
        color='blue', 
        # with label the first value in first_name
        label='Heuristic Cost') 

# Create a bar with Local Cost data,
# in position pos + some width buffer
plt.bar([p + width for p in pos], 
        #using plot_data['Local Cost'] data,
        plot_data['Local Cost'], 
        # of width
        width, 
        # with color
        color='orange', 
        # with label the second value in first_name
        label='Local Cost') 

# Set the y axis label
ax.set_ylabel('Cost')

# Set the x axis label
ax.set_xlabel('Iteration')

# Set the chart's title
ax.set_title('Superosed Bar Plot of Heuristic and Local Costs')

# Add a legend
ax.legend()

# Set the position of the x ticks
ax.set_xticks([p + width/2 for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(plot_data['Iteration'])

# Adding the legend and showing the plot
plt.legend(['Heuristic Cost', 'Local Cost'], loc='upper right')
plt.grid()
plt.show()

# %%
dataset.columns
# Out:
# Index(['iter', 'inst', 'objectif', 'chosen_tacticoneboat', 'chosen_reversed',
#        'chosen_tacticallboats', 'chosen_reversedtacticallboats',
#        'chosen_tacticlocalsearch', 'chosen_indexoneship',
#        'chosen_indexallship', 'chosen_indexreversedallship',
#        'chosen_indexrateconstrained', 'chosen_indexproptoremove', 'Heur Cost',
#        'Delay Cost Heur', 'Waiting Cost Heur', 'Penalty Heur',
#        'Handling Cost Heur', 'Fuel Cost Heur', 'Local Cost',
#        'Delay Cost Local', 'Waiting Cost Local', 'Penalty Local',
#        'Handling Cost Local', 'Fuel Cost Local', 'timeheur', 'timelocal',
#        'proba_tacticboat', 'proba_tacticall', 'proba_tacticlocalsearch',
#        'oneboatdistance', 'oneboatcost', 'oneboattime', 'allboatsdist',
#        'allboatstime', 'allboatscost', 'rateconstained', 'failed', 'better',
#        'reconstruct', 'pathrelinking', 'usedLocalSearch', 'average_cost_elite',
#        'average_dist_elite', 'pushimprove'],
#       dtype='object')

# %%
# Group by 'iter' and extract the relevant cost columns
average_costs = dataset.groupby('iter').agg({
    'Heur Cost': 'first',
    'Local Cost': 'first',
    'Delay Cost Local': 'first',
    'Penalty Local': 'first',
    'Fuel Cost Local': 'first',
    'Handling Cost Local': 'first',
    'Waiting Cost Local': 'first',
    'Delay Cost Heur': 'first',
    'Penalty Heur': 'first',
    'Fuel Cost Heur': 'first',
    'Handling Cost Heur': 'first',
    'Waiting Cost Heur': 'first',
    'better':'first',
    'usedLocalSearch':'first'
}).reset_index()

# Costs for plotting
costs_for_plotting = [
    ('Local Cost','Heur Cost', 'Total Cost'),
    ('Delay Cost Local','Delay Cost Heur', 'Delay Cost'),
    ('Waiting Cost Local', 'Waiting Cost Heur', 'Waiting Cost'),
    ('Penalty Local', 'Penalty Heur', 'Penalty Cost'),
    ('Handling Cost Local', 'Handling Cost Heur', 'Handling Cost'),
    ('Fuel Cost Local', 'Fuel Cost Heur', 'Fuel Cost')
]

iterations = average_costs['iter']



# Plotting
for cost_local, cost_heur, cost_name in costs_for_plotting:
    plt.figure(figsize=(10, 5))

    # Calculate the relative difference as a percentage
    relative_difference = 100 * (average_costs[cost_local] - dataset[cost_heur]) / average_costs[cost_heur]

    # Plot the line
    plt.plot(iterations, relative_difference, label='Relative Difference (%)', marker='o')

    # Adding titles and labels
    plt.title(f'Relative Difference in {cost_name} Over Iterations')
    plt.xlabel('Iteration')
    plt.ylabel('Relative Difference (%)')
    plt.legend()

    # Show plot
    plt.show()

# %%
average_costs[average_costs['usedLocalSearch']==1]
# Out:
#       iter  Heur Cost  Local Cost  Delay Cost Local  Penalty Local  \
# 0        1  2405721.0   2405721.0         1023687.0            0.0
# 2        3  2725349.0   2560965.0         1146968.0            0.0
# 3        4  2292980.0   2286200.0          955215.0            0.0
# 8        9  2442188.0   2442188.0         1058366.0            0.0
# 17      18  2354852.0   2343871.0          983158.0            0.0
# ...    ...        ...         ...               ...            ...
# 1890  1891  2472128.0   2398596.0         1016093.0        24924.0
# 1891  1892  2541852.0   2541852.0         1131419.0            0.0
# 1892  1893  2427556.0   2406531.0         1050222.0            0.0
# 1893  1894  2341643.0   2341643.0         1004188.0            0.0
# 1898  1899  2361702.0   2283243.0          954466.0            0.0
#
#       Fuel Cost Local  Handling Cost Local  Waiting Cost Local  \
# 0            884635.0             328937.0            168464.0
# 2            868703.0             340922.0            209406.0
# 3            833312.0             335140.0            168717.0
# 8            838824.0             327169.0            217831.0
# 17           868151.0             338997.0            173507.0
# ...               ...                  ...                 ...
# 1890         884874.0             336949.0            138280.0
# 1891         850024.0             335718.0            224692.0
# 1892         872803.0             325484.0            179982.0
# 1893         832612.0             343826.0            161019.0
# 1898         806357.0             323084.0            199387.0
#
#       Delay Cost Heur  Penalty Heur  Fuel Cost Heur  Handling Cost Heur  \
# 0           1023687.0           0.0        884635.0            328937.0
# 2           1179320.0      164649.0        853719.0            355213.0
# 3            994829.0           0.0        824248.0            347987.0
# 8           1058366.0           0.0        838824.0            327169.0
# 17           994037.0       56151.0        857617.0            346250.0
# ...               ...           ...             ...                 ...
# 1890        1092990.0           0.0        878594.0            337690.0
# 1891        1131419.0           0.0        850024.0            335718.0
# 1892        1082571.0       13401.0        813789.0            336650.0
# 1893        1004188.0           0.0        832612.0            343826.0
# 1898         990811.0           0.0        820307.0            334142.0
#
#       Waiting Cost Heur  better  usedLocalSearch
# 0              168464.0     1.0                1
# 2              172450.0     0.0                1
# 3              125917.0     0.0                1
# 8              217831.0     0.0                1
# 17             100798.0     0.0                1
# ...                 ...     ...              ...
# 1890           162856.0     0.0                1
# 1891           224692.0     0.0                1
# 1892           181147.0     0.0                1
# 1893           161019.0     0.0                1
# 1898           216443.0     0.0                1
#
# [587 rows x 15 columns]

# %%
import pandas as pd

# Dictionary to store the mean relative differences for each cost type
mean_relative_differences = {}

# Calculate mean relative differences
for cost_local, cost_heur, cost_name in costs_for_plotting:
    # Calculate the relative difference as a percentage
    relative_difference = (average_costs[average_costs['usedLocalSearch']==1][cost_local] - average_costs[average_costs['usedLocalSearch']==1][cost_heur])
    # Calculate the mean relative difference and store it in the dictionary
    mean_relative_differences[cost_name] = relative_difference.mean()

# Convert the dictionary into a pandas DataFrame
mean_relative_differences_df = pd.DataFrame(list(mean_relative_differences.items()), columns=['Cost Type', 'Mean Relative Difference'])

# Plotting
plt.figure(figsize=(10, 5))
mean_relative_differences_df.plot(x='Cost Type', y='Mean Relative Difference', kind='bar', legend=False)
plt.title('Mean Relative Differences for Each Cost Type')
plt.ylabel('Mean Relative Difference (%)')
plt.xlabel('Cost Type')
plt.xticks(rotation=45)
plt.show()

# %%
# List of column pairs (local and heuristic costs) and their labels
cost_pairs = [
    ('Local Cost', 'Heur Cost', 'Total Cost'),
    ('Delay Cost Local', 'Delay Cost Heur', 'Delay Cost'),
    ('Waiting Cost Local', 'Waiting Cost Heur', 'Waiting Cost'),
    ('Penalty Local', 'Penalty Heur', 'Penalty'),
    ('Handling Cost Local', 'Handling Cost Heur', 'Handling Cost'),
    ('Fuel Cost Local', 'Fuel Cost Heur', 'Fuel Cost')
]

# Calculate the differences between local and heuristic costs for each type
cost_differences = pd.DataFrame()

for local, heur, label in cost_pairs:
    cost_differences[label] = all_datasets[all_datasets['usedLocalSearch']==1].groupby('inst_type')[local].mean() - all_datasets[all_datasets['usedLocalSearch']==1].groupby('inst_type')[heur].mean()
# Transpose the DataFrame to have inst_type as columns
cost_differences = cost_differences.transpose()

# %%
cost_differences
# Out:
# inst_type               2_1           2_3           4_1           4_3
# Total Cost    -23408.980903 -21853.230894 -25810.854785 -28820.405451
# Delay Cost    -15011.201389 -14417.804878 -17005.468647 -19867.844974
# Waiting Cost    2234.142361   3939.507317   1420.455446   3095.347530
# Penalty        -9879.739583 -10298.003252  -9856.471947  -8987.921635
# Handling Cost   -990.197917   -694.011382  -1780.366337  -1232.034072
# Fuel Cost       9702.579861   5642.887805   8189.566007   3964.362862

# %%
# Create a bar plot
bar_width = 0.15
bar_positions = np.arange(len(cost_differences.index))  # position of the bars
bar_labels = cost_differences.columns  # labels for the bars, which are the inst_types

plt.figure(figsize=(12, 6))

for i, label in enumerate(bar_labels):
    plt.bar(bar_positions + i * bar_width, cost_differences[label], width=bar_width, label=label)

plt.xlabel('Cost Type')
plt.ylabel('Mean Cost Difference')
plt.title('Mean Cost Difference for Each Cost Type')
plt.xticks(bar_positions + bar_width * (len(bar_labels) - 1) / 2, cost_differences.index, rotation=45)
plt.legend(title='inst_type')
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Dictionary to store the mean relative differences for each cost type
mean_relative_differences = {}

# Calculate mean relative differences
for cost_local, cost_heur, cost_name in costs_for_plotting:
    # Calculate the relative difference as a percentage
    relative_difference =  (average_costs[average_costs['better']==1][cost_local] - average_costs[average_costs['better']==1][cost_heur])
    # Calculate the mean relative difference and store it in the dictionary
    mean_relative_differences[cost_name] = relative_difference.mean()

# Convert the dictionary into a pandas DataFrame
mean_relative_differences_df = pd.DataFrame(list(mean_relative_differences.items()), columns=['Cost Type', 'Mean Relative Difference'])

# Plotting
plt.figure(figsize=(10, 5))
mean_relative_differences_df.plot(x='Cost Type', y='Mean Relative Difference', kind='bar', legend=False)
plt.title('Mean Relative Differences for Each Cost Type')
plt.ylabel('Mean Relative Difference (%)')
plt.xlabel('Cost Type')
plt.xticks(rotation=45)
plt.show()

# %%
average_costs
# Out:
#       iter  Heur Cost  Local Cost  Delay Cost Local  Penalty Local  \
# 0        1  2692949.0   2676939.0         1249673.0        20883.0
# 1        2  2497904.0   2455105.0         1117314.0            0.0
# 2        3  3941171.0   3941171.0         1872764.0       563616.0
# 3        4  3303423.0   3303423.0         1565594.0       278820.0
# 4        5  3153903.0   3153903.0         1422732.0       369060.0
# ...    ...        ...         ...               ...            ...
# 2041  2042  3615771.0   3615771.0         1684265.0       418811.0
# 2042  2043  2889251.0   2889251.0         1419730.0        39476.0
# 2043  2044  3608748.0   3608748.0         1564529.0       656333.0
# 2044  2045  2883162.0   2883162.0         1322022.0       204280.0
# 2045  2046  2316575.0   2294068.0          933233.0            0.0
#
#       Fuel Cost Local  Handling Cost Local  Waiting Cost Local  \
# 0            845665.0             352116.0            208604.0
# 1            865575.0             341653.0            160983.0
# 2            876132.0             397497.0            231164.0
# 3            881058.0             389659.0            188294.0
# 4            830766.0             388088.0            143258.0
# ...               ...                  ...                 ...
# 2041         829139.0             412443.0            271115.0
# 2042         834950.0             365887.0            229210.0
# 2043         904013.0             373019.0            110855.0
# 2044         837948.0             369661.0            149252.0
# 2045         849353.0             324946.0            189288.0
#
#       Delay Cost Heur  Penalty Heur  Fuel Cost Heur  Handling Cost Heur  \
# 0           1261120.0       40500.0        830500.0            360347.0
# 1           1142430.0        3622.0        843025.0            337597.0
# 2           1872764.0      563616.0        876132.0            397497.0
# 3           1565594.0      278820.0        881058.0            389659.0
# 4           1422732.0      369060.0        830766.0            388088.0
# ...               ...           ...             ...                 ...
# 2041        1684265.0      418811.0        829139.0            412443.0
# 2042        1419730.0       39476.0        834950.0            365887.0
# 2043        1564529.0      656333.0        904013.0            373019.0
# 2044        1322022.0      204280.0        837948.0            369661.0
# 2045         961228.0           0.0        827757.0            331247.0
#
#       Waiting Cost Heur
# 0              200483.0
# 1              171233.0
# 2              231164.0
# 3              188294.0
# 4              143258.0
# ...                 ...
# 2041           271115.0
# 2042           229210.0
# 2043           110855.0
# 2044           149252.0
# 2045           196343.0
#
# [2046 rows x 13 columns]
